# %% [markdown]
# <a href="https://colab.research.google.com/github/aelshehawy/text-as-data-computational-text-analysis-oxford/blob/main/Code%20Solutions/TextasData_Session2_Excercise_Solutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Excercises**

# %% [markdown]
# ## Excercise 1 - Create 3 different cleaning pipelines on Data Day 1 files
#
# **Only use files that have text in their name**
#
#
# 1.   using no stemming and lemmatization
# 2.   using a stemmer
# 3.   using a lemmatizer
#
# Experiment with the order of the pre-processing steps - report how each step gets different

# %%
#one example of how you can do this
#this is using no stemmer and no lemmatizer
#you just keep adding needed steps to your pipeline

# %%
def clean(text):
    text=text.replace('\n\n','')
    text=text.lower()
    text= re.sub('[^A-Za-z0-9]+', ' ', text)
    text=re.sub(r'[0-9]+', " ", text)
    text=text.split() 
    text=[word for word in text if word not in stopwords.words('english')]
    text=" ".join(str(text) for text in text)
    return text

# %%
import codecs
import os

articles_new=[]
for filename in os.listdir("/content/drive/MyDrive/Colab Notebooks/Oxford Text Analysis/Data/Data Day 1/"):
    #print(filename)
    if "text" in filename:
        print(filename)
        document = open("/content/drive/MyDrive/Colab Notebooks/Oxford Text Analysis/Data/Data Day 1/"+filename,"r")
       # print(document)
        document2 = document.read()
       # print(document2)
        document3=clean(document2)
        #print(document3)
        articles_new.append(document3)
# Out:
# text3.txt
# text7.txt
# text6.txt
# text10.tsv
# text9.txt
# text8.txt
# text2.txt
# text10
# text4.txt
# text1.txt
# text5.txt

# %%
print(articles_new)
print(len(articles_new))
# Out:
# ['http de sputniknews compolitik deutschland spd nahles hartz iv http web archive org web https de sputniknews com amp politik deutschland spd nahles hartz iv pr zisiert nahles ihre idee f r hartz iv alternative vars counterid requests pageview http web archive org web https counter yadro ru hit rs total sputniki total sputniknews u ampdocurl r documentreferrer screenwidth screenheight h title random triggers track pageview visible request pageview alle nachrichtenpolitik reuters hannibal hanschkeso pr zisiert nahles ihre idee f r hartz iv alternative aktualisiert zum kurzlinkdie spd parteichefin andrea nahles hat einem gastbeitrag f r die frankfurter allgemeine zeitung eine abl sung des hartz iv systems durch h mindestl hne zusch sse zu sozialabgaben und steuerboni gefordert beim debattencamp berlin vor einer woche k ndigte nahles einen komplettumbau des sozialstaates sowie die abschaffung von hartz iv dessen monatlicher satz euro betr gt nun konkretisiert sie ihre vorstellungen vie
# ...

# %%
#you can also transform the list to a pandas data frame
df = pd.DataFrame({'col':articles_new})
df
# Out:
#                                                   col
# 0   http de sputniknews compolitik deutschland spd...
# 1   http de sputniknews comkarikatur http web arch...
# 2   http de sputniknews compolitik warschau gegen ...
# 3   http de sputniknews compolitik usa verschaerfe...
# 4   http de sputniknews compolitik syrien deutschl...
# 5   http de sputniknews compolitik syrien deutschl...
# 6   http de sputniknews com panorama html http web...
# 7   http de sputniknews compolitik usa verschaerfe...
# 8   http de sputniknews compolitik trump usa asyl ...
# 9   http de sputniknews compolitik lindner merkel ...
# 10  http de sputniknews compolitik oesterreich dra...

# %% [markdown]
# ## Excercise 2 - Count number of topics
#
# Open the rt_dataset_small.tsv count the number of times each topic appears in the dataset
#
# *Hint: Check dataset structure and use indexing to extract topics. You can use a loop or list comprehension

# %%
import codecs
dataset = codecs.open("/content/drive/MyDrive/Colab Notebooks/Oxford Text Analysis/Data/rt_dataset_small.tsv", "r", "utf-8").read().strip().split("\n") 
# we split by line breaks

# %%
# how to count the number of topics? [can be homework]

topics = []
for line in dataset:
    topic = line.split("\t")[2]
    topics.append(topic)

print(topics)
# Out:
# ['topic ', 'news', 'shows', 'uk', 'usa', 'sport', 'news', 'usa', 'usa', 'uk', 'news', 'business', 'news', 'usa', 'news', 'shows', 'usa', 'sport', 'usa', 'uk', 'op-edge', 'news', 'news', 'op-edge', 'business', 'politics', 'news', 'shows', 'viral', 'uk', 'op-edge', 'in-motion', 'politics', 'usa', 'op-edge', 'usa', 'shows', 'news', 'viral', 'news', 'in-motion', 'in-motion', 'op-edge', 'usa', 'news', 'sport', 'in-motion', 'viral', 'uk', 'in-motion', 'sport', 'politics', 'op-edge', 'usa', 'news', 'uk', 'op-edge', 'uk', 'op-edge', 'news', 'news', 'uk', 'news', 'business', 'news', 'sport', 'business', 'news', 'politics', 'usa', 'usa', 'news', 'news', 'op-edge', 'news', 'usa', 'uk', 'shows', 'viral', 'in-motion', 'news', 'sport', 'news', 'politics', 'uk', 'politics', 'politics', 'news', 'in-motion', 'usa', 'usa', 'in-motion', 'in-motion', 'politics', 'news', 'news', 'uk', 'sport', 'usa', 'politics', 'in-motion', 'op-edge', 'sport', 'news', 'in-motion', 'usa', 'in-motion', 'news', 'op-edge', 
# ...

# %%
from collections import Counter

print (Counter(topics).most_common(30))
# Out:
# [('news', 2726), ('usa', 1860), ('uk', 1123), ('op-edge', 1098), ('in-motion', 920), ('business', 883), ('viral', 850), ('sport', 838), ('politics', 509), ('shows', 356), ('on-air', 9), ('topic ', 1), ('about-us', 1), ('360', 1), ('business-projects', 1)]

# %%
#using list comprehension
topics = [line.split("\t")[2] for line in dataset]

from collections import Counter

print (Counter(topics).most_common(30))
# Out:
# [('news', 2726), ('usa', 1860), ('uk', 1123), ('op-edge', 1098), ('in-motion', 920), ('business', 883), ('viral', 850), ('sport', 838), ('politics', 509), ('shows', 356), ('on-air', 9), ('topic ', 1), ('about-us', 1), ('360', 1), ('business-projects', 1)]

# %% [markdown]
# ## Excercise 3 - Counting and creating new variables
#
# This data set is about congressional sanctions. Each document of the congress that issues sanctions has a different id, saved in the column id-snippet
#
# 1. Load data - sascat_excerpt.tsv in a pandas dataframe
# 2. Rename the last variable = content
# 3. get the averages a) of the number of words, b) number of sentences
# 3. keep only these columns id-snippet and content
# 5. count number of words in content column, create a new column and paste the total count there
# 6. Save in a new column called cleantext - the content (column content) after you preprocess it with a fucntion in **one step** - you can choose any pre-processing steps you see necessary
# 7. export data as tsv
#
# *Hint - you can use pandas

# %%
#1
import pandas as pd 

sascat = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Oxford Text Analysis/Data/sascat_excerpt.tsv',delimiter="\t")
sascat
# Out:
#        id-snippet  ...                                        Unnamed: 10
# 0    hr5114-101.1  ...  Provides for the enforcement of all provisions...
# 1    hr5114-101.2  ...  Requires the delivery of excess defense articl...
# 2    hr5114-101.3  ...  Prohibits making available any ESF or foreign ...
# 3    hr5114-101.4  ...  Prohibits the obligation of funds for the Euro...
# 4    hr5114-101.5  ...  Prohibits assistance to countries which fail t...
# 5    hr5114-101.6  ...  Requires agreements for the sale or provision ...
# 6    hr5114-101.7  ...  Limits the amount of military assistance for E...
# 7    hr5114-101.8  ...  Earmarks specified amounts of ESF assistance f...
# 8    hr5114-101.9  ...  Prohibits any foreign military financing for Z...
# 9    hr3199-109.1  ...  Amends the Foreign Assistance Act of 1961 to r...
# 10   hr3199-109.2  ...  Amends the federal criminal code to provide fo...
# 11   hr5948-109.1  ...  Authorizes the President to deny U.S. entry to...
# ...

# %%
#2
sascat = sascat.rename({"Unnamed: 10": 'content'}, axis=1)
sascat
# Out:
#        id-snippet  ...                                            content
# 0    hr5114-101.1  ...  Provides for the enforcement of all provisions...
# 1    hr5114-101.2  ...  Requires the delivery of excess defense articl...
# 2    hr5114-101.3  ...  Prohibits making available any ESF or foreign ...
# 3    hr5114-101.4  ...  Prohibits the obligation of funds for the Euro...
# 4    hr5114-101.5  ...  Prohibits assistance to countries which fail t...
# 5    hr5114-101.6  ...  Requires agreements for the sale or provision ...
# 6    hr5114-101.7  ...  Limits the amount of military assistance for E...
# 7    hr5114-101.8  ...  Earmarks specified amounts of ESF assistance f...
# 8    hr5114-101.9  ...  Prohibits any foreign military financing for Z...
# 9    hr3199-109.1  ...  Amends the Foreign Assistance Act of 1961 to r...
# 10   hr3199-109.2  ...  Amends the federal criminal code to provide fo...
# 11   hr5948-109.1  ...  Authorizes the President to deny U.S. entry to...
# ...

# %%
#3 get averages
print(int(sascat["n-nouns"].mean()))
print(int(sascat["n-sentences"].mean()))
# Out:
# 55
# 3

# %%
#keep columns

sascat = sascat[['content','id-snippet']]
sascat
# Out:
#                                               content     id-snippet
# 0   Provides for the enforcement of all provisions...   hr5114-101.1
# 1   Requires the delivery of excess defense articl...   hr5114-101.2
# 2   Prohibits making available any ESF or foreign ...   hr5114-101.3
# 3   Prohibits the obligation of funds for the Euro...   hr5114-101.4
# 4   Prohibits assistance to countries which fail t...   hr5114-101.5
# 5   Requires agreements for the sale or provision ...   hr5114-101.6
# 6   Limits the amount of military assistance for E...   hr5114-101.7
# 7   Earmarks specified amounts of ESF assistance f...   hr5114-101.8
# 8   Prohibits any foreign military financing for Z...   hr5114-101.9
# 9   Amends the Foreign Assistance Act of 1961 to r...   hr3199-109.1
# 10  Amends the federal criminal code to provide fo...   hr3199-109.2
# 11  Authorizes the President to deny U.S. entry to...   hr5948-109.1
# 12  (Sec. 527) Prohibits bilateral assistance fund...   hjres2-108.1
# ...

# %%
# you can split by white space count the number of words and put them in a new column 
sascat['totalwords'] = sascat['content'].str.split().str.len()
sascat
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                               content  ... totalwords
# 0   Provides for the enforcement of all provisions...  ...        839
# 1   Requires the delivery of excess defense articl...  ...        159
# 2   Prohibits making available any ESF or foreign ...  ...         56
# 3   Prohibits the obligation of funds for the Euro...  ...        110
# 4   Prohibits assistance to countries which fail t...  ...         27
# 5   Requires agreements for the sale or provision ...  ...         45
# 6   Limits the amount of military assistance for E...  ...        465
# ...

# %%
#pre-process content

import re
def clean_sanctions(sometextasargument):
    # note that whatever we pass to function as argument when invoked will become assigned to object sometextasargument, 
    # will then be assigned to object text which will keep changing until we assign it to object sometextasoutput
    text=sometextasargument.replace('\n\n','')
    text=text.lower()
    text= re.sub('[^A-Za-z0-9]+', ' ', text)
    text=re.sub(r'[0-9]+', " ", text)     
    sometextasoutput=text
    # finally, we ask the function returns what it did:  
    return (sometextasoutput)

   
sascat["cleanedtext"]=sascat["content"].apply(clean_sanctions) 
sascat.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
#                                              content  ...                                        cleanedtext
# 0  Provides for the enforcement of all provisions...  ...  provides for the enforcement of all provisions...
# 1  Requires the delivery of excess defense articl...  ...  requires the delivery of excess defense articl...
# 2  Prohibits making available any ESF or foreign ...  ...  prohibits making available any esf or foreign ...
# 3  Prohibits the obligation of funds for the Euro...  ...  prohibits the obligation of funds for the euro...
# ...

# %%
#export
sascat.to_csv("sascat_excercises.csv", sep='\t', encoding='utf-8')

# %% [markdown]
# ## Excercise 4 - NER
#
#
# **Extract** the most popular 30 NERs (not entities!) from the entire corpus of the rt_dataset_small.tsv
#
# - Only check the text/content of articles in the dataset
# - Focus only on articles that include Trump and Hillary within the same article
# - Choose appropriate text-preprocessing steps
# - USE NER to extract the

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
import codecs, nltk

dataset = codecs.open("/content/drive/MyDrive/Colab Notebooks/Oxford Text Analysis/Data/rt_dataset_small", "r", "utf-8").read().strip().split("\n")


from collections import Counter

box = []

# how to quickly find an article from the dataset
for k in range(len(dataset)):
    article = dataset[k]
    if "Trump" in article and "Hillary" in article:
        article = dataset[4].split("\t")[3]
        
        # first step you tokenize (read documentation to know the input of NER)
        article = nltk.word_tokenize(article)

        # you use the pos-tagger (it gives you back a list of tuples (word,pos))
        pos_article = nltk.pos_tag(article)

        # then you use the NER library
        ner = nltk.ne_chunk(pos_article)
        
        ner = [x[0][0] for x in ner if type(x) == nltk.tree.Tree]
        
        for entity in ner:
            box.append(entity)

# %%
box
# Out:
# ['Israel',
#  'SodaStream',
#  'Daniel',
#  'Netanyahu',
#  'Palestinian',
#  'Birnbaum',
#  'SodaStream',
#  'West',
#  'Israel',
#  'Birnbaum',
#  'Israeli',
#  'SodaStream',
#  'Boycott',
#  'Divestment',
#  'Sanctions',
#  'BDS',
#  'Netanyahu',
#  'Palestinian',
#  'Birnbaum',
#  'Palestinian',
#  'Israel',
#  'Netanyahu',
#  'Birnbaum',
#  'CEO',
#  'Netanyahu',
#  'Bibi',
#  'Netanyahu',
#  'Birnbaum',
#  'Israel',
#  'Jews',
#  'Arabs',
#  'Orthodox',
#  'Unsurprisingly',
#  'Netanyahu',
#  'Israel',
#  'Birnbaum',
#  'BDS',
#  'SodaStream',
#  'West',
#  'Israel',
#  'Israeli',
#  'Israeli',
#  'SodaStream',
#  'Mishor',
#  'Green',
#  'Israeli',
#  'Palestinian',
#  'Birnbaum',
#  'Netanyahu',
#  'PM',
#  'Birnbaum',
#  'Palestinian',
#  'PM',
#  'Birnbaum',
#  'Netanyahu',
#  'SodaStream',
#  'Palestinians',
#  'Israel',
#  'Palestinians',
#  'Israel',
#  'Israel',
#  'SodaStream',
#  'Daniel',
#  'Netanyahu',
#  'Palestinian',
#  'Birnbaum',
#  'SodaStream',
#  'West',
# ...

# %%
count = Counter(box)

print (count.most_common(30))
# Out:
# [('Birnbaum', 279), ('Israel', 248), ('Netanyahu', 248), ('SodaStream', 186), ('Palestinian', 155), ('Israeli', 124), ('West', 62), ('BDS', 62), ('PM', 62), ('Palestinians', 62), ('Daniel', 31), ('Boycott', 31), ('Divestment', 31), ('Sanctions', 31), ('CEO', 31), ('Bibi', 31), ('Jews', 31), ('Arabs', 31), ('Orthodox', 31), ('Unsurprisingly', 31), ('Mishor', 31), ('Green', 31)]

# %%
from collections import Counter

box = []

# how to quickly find an article from the dataset
for k in range(len(dataset)):
    article = dataset[k]
    if "Trump" in article and "Hillary" in article:
        article = dataset[4].split("\t")[3]
        
        # first step you tokenize (read documentation to know the input of NER)
        article = nltk.word_tokenize(article)

        # you use the pos-tagger (it gives you back a list of tuples (word,pos))
        pos_article = nltk.pos_tag(article)

        # then you use the NER library
        ner = nltk.ne_chunk(pos_article)
        print(ner)
        ner = [x[0][1] for x in ner if type(x) == nltk.tree.Tree]
        
        for entity in ner:
            box.append(entity)
# Out:
# Streaming output truncated to the last 5000 lines.
#   that/IN
#   (ORGANIZATION SodaStream/NNP)
#   was/VBD
#   forced/VBN
#   to/TO
#   move/VB
#   due/RB
#   to/TO
#   the/DT
#   pressure/NN
#   from/IN
#   the/DT
#   pro-Palestinian/JJ
#   (PERSON Boycott/NNP)
#   ,/,
#   (ORGANIZATION Divestment/NNP)
#   and/CC
#   (GPE Sanctions/NNP)
#   (/(
#   (ORGANIZATION BDS/NNP)
#   )/)
#   movement/NN
#   ,/,
#   as/RB
#   well/RB
#   as/IN
#   fire/NN
#   the/DT
#   500/CD
#   Palestinians/NNPS
#   working/VBG
#   there/RB
#   ./.
#   But/CC
#   the/DT
#   company/NN
#   insists/VBZ
#   that/IN
#   despite/IN
#   claims/NNS
#   from/IN
#   the/DT
#   (GPE Netanyahu/NNP)
#   government/NN
#   ,/,
#   it/PRP
#   wanted/VBD
#   to/TO
#   retain/VB
#   350/CD
#   of/IN
#   its/PRP$
#   500/CD
#   (GPE Palestinian/JJ)
#   employees/NNS
#   to/TO
#   work/VB
#   at/IN
#   its/PRP$
#   new/JJ
#   plant/NN
#   in/IN
#   the/DT
#   Negev/NNP
#   ./.
#   However/RB
#   ,/,
#   according/VBG
# ...

# %%
box
# Out:
# ['NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'JJ',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'JJ',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'JJ',
#  'NNP',
#  'JJ',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'JJ',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'JJ',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNPS',
#  'NNP',
#  'NNPS',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'JJ',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'JJ',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'JJ',
#  'NNP',
#  'JJ',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
# ...
